# %% [markdown]
# # Module Five Assignment: Cartpole Problem
# Review the code in this notebook and in the score_logger.py file in the *scores* folder (directory). Once you have reviewed the code, return to this notebook and select **Cell** and then **Run All** from the menu bar to run this code. The code takes several minutes to run.

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  
  
GAMMA = 0.95  
LEARNING_RATE = 0.001  
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  
  
EXPLORATION_MAX = 1.0  
EXPLORATION_MIN = 0.01  
EXPLORATION_DECAY = 0.995  
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()
# Out:
# Using TensorFlow backend.

# %%
cartpole()
# Out:
# Run: 1, exploration: 0.9046104802746175, score: 40
# Scores: (min: 40, avg: 40, max: 40)
#
# Run: 2, exploration: 0.8390886103705794, score: 16
# Scores: (min: 16, avg: 28, max: 40)
#
# Run: 3, exploration: 0.7744209942832988, score: 17
# Scores: (min: 16, avg: 24.333333333333332, max: 40)
#
# Run: 4, exploration: 0.7328768546436799, score: 12
# Scores: (min: 12, avg: 21.25, max: 40)
#
# Run: 5, exploration: 0.6662995813682115, score: 20
# Scores: (min: 12, avg: 21, max: 40)
#
# Run: 6, exploration: 0.5937455908197752, score: 24
# Scores: (min: 12, avg: 21.5, max: 40)
#
# Run: 7, exploration: 0.5452463540625918, score: 18
# Scores: (min: 12, avg: 21, max: 40)
#
# Run: 8, exploration: 0.47622912292284103, score: 28
# Scores: (min: 12, avg: 21.875, max: 40)
#
# Run: 9, exploration: 0.3995984329713264, score: 36
# Scores: (min: 12, avg: 23.444444444444443, max: 40)
#
# Run: 10, exploration: 0.3455358541129786, score: 30
# Scores: (min: 12, avg: 24.1, max: 40)
#
# Run: 11, exploration: 0.18099664897669618, score: 130
# Scores: (min: 12, avg: 33.72727272727273, max: 130)
#
# Run: 12, exploration: 0.14372497725712216, score: 47
# Scores: (min: 12, avg: 34.833333333333336, max: 130)
#
# Run: 13, exploration: 0.12743425563174798, score: 25
# Scores: (min: 12, avg: 34.07692307692308, max: 130)
#
# Run: 14, exploration: 0.11820406108847166, score: 16
# Scores: (min: 12, avg: 32.785714285714285, max: 130)
#
# Run: 15, exploration: 0.09292664835904782, score: 49
# Scores: (min: 12, avg: 33.86666666666667, max: 130)
#
# Run: 16, exploration: 0.07018314008827135, score: 57
# Scores: (min: 12, avg: 35.3125, max: 130)
#
# Run: 17, exploration: 0.058889873488111255, score: 36
# Scores: (min: 12, avg: 35.35294117647059, max: 130)
#
# Run: 18, exploration: 0.052741004581916356, score: 23
# Scores: (min: 12, avg: 34.666666666666664, max: 130)
#
# Run: 19, exploration: 0.03983280768576652, score: 57
# Scores: (min: 12, avg: 35.8421052631579, max: 130)
#
# Run: 20, exploration: 0.03621424652392737, score: 20
# Scores: (min: 12, avg: 35.05, max: 130)
#
# Run: 21, exploration: 0.03392965965983891, score: 14
# Scores: (min: 12, avg: 34.04761904761905, max: 130)
#
# Run: 22, exploration: 0.022835098131175, score: 80
# Scores: (min: 12, avg: 36.13636363636363, max: 130)
#
# Run: 23, exploration: 0.015917127532080494, score: 73
# Scores: (min: 12, avg: 37.73913043478261, max: 130)
#
# Run: 24, exploration: 0.011039504743095268, score: 74
# Scores: (min: 12, avg: 39.25, max: 130)
#
# Run: 25, exploration: 0.01, score: 106
# Scores: (min: 12, avg: 41.92, max: 130)
#
# Run: 26, exploration: 0.01, score: 137
# Scores: (min: 12, avg: 45.57692307692308, max: 137)
#
# Run: 27, exploration: 0.01, score: 91
# Scores: (min: 12, avg: 47.25925925925926, max: 137)
#
# Run: 28, exploration: 0.01, score: 173
# Scores: (min: 12, avg: 51.75, max: 173)
#
# Run: 29, exploration: 0.01, score: 82
# Scores: (min: 12, avg: 52.793103448275865, max: 173)
#
# Run: 30, exploration: 0.01, score: 78
# Scores: (min: 12, avg: 53.63333333333333, max: 173)
#
# Run: 31, exploration: 0.01, score: 225
# Scores: (min: 12, avg: 59.16129032258065, max: 225)
#
# Run: 32, exploration: 0.01, score: 145
# Scores: (min: 12, avg: 61.84375, max: 225)
#
# Run: 33, exploration: 0.01, score: 79
# Scores: (min: 12, avg: 62.36363636363637, max: 225)
#
# Run: 34, exploration: 0.01, score: 202
# Scores: (min: 12, avg: 66.47058823529412, max: 225)
#
# Run: 35, exploration: 0.01, score: 148
# Scores: (min: 12, avg: 68.8, max: 225)
#
# Run: 36, exploration: 0.01, score: 121
# Scores: (min: 12, avg: 70.25, max: 225)
#
# Run: 37, exploration: 0.01, score: 128
# Scores: (min: 12, avg: 71.8108108108108, max: 225)
#
# Run: 38, exploration: 0.01, score: 134
# Scores: (min: 12, avg: 73.44736842105263, max: 225)
#
# Run: 39, exploration: 0.01, score: 257
# Scores: (min: 12, avg: 78.15384615384616, max: 257)
#
# Run: 40, exploration: 0.01, score: 144
# Scores: (min: 12, avg: 79.8, max: 257)
#
# Run: 41, exploration: 0.01, score: 158
# Scores: (min: 12, avg: 81.70731707317073, max: 257)
#
# Run: 42, exploration: 0.01, score: 234
# Scores: (min: 12, avg: 85.33333333333333, max: 257)
#
# Run: 43, exploration: 0.01, score: 197
# Scores: (min: 12, avg: 87.93023255813954, max: 257)
#
# Run: 44, exploration: 0.01, score: 207
# Scores: (min: 12, avg: 90.63636363636364, max: 257)
#
# Run: 45, exploration: 0.01, score: 219
# Scores: (min: 12, avg: 93.4888888888889, max: 257)
#
# Run: 46, exploration: 0.01, score: 314
# Scores: (min: 12, avg: 98.28260869565217, max: 314)
#
# Run: 47, exploration: 0.01, score: 163
# Scores: (min: 12, avg: 99.65957446808511, max: 314)
#
# Run: 48, exploration: 0.01, score: 224
# Scores: (min: 12, avg: 102.25, max: 314)
#
# Run: 49, exploration: 0.01, score: 175
# Scores: (min: 12, avg: 103.73469387755102, max: 314)
#
# Run: 50, exploration: 0.01, score: 241
# Scores: (min: 12, avg: 106.48, max: 314)
#
# Run: 51, exploration: 0.01, score: 224
# Scores: (min: 12, avg: 108.7843137254902, max: 314)
#
# Run: 52, exploration: 0.01, score: 189
# Scores: (min: 12, avg: 110.32692307692308, max: 314)
#
# Run: 53, exploration: 0.01, score: 222
# Scores: (min: 12, avg: 112.43396226415095, max: 314)
#
# Run: 54, exploration: 0.01, score: 225
# Scores: (min: 12, avg: 114.51851851851852, max: 314)
#
# Run: 55, exploration: 0.01, score: 163
# Scores: (min: 12, avg: 115.4, max: 314)
#
# Run: 56, exploration: 0.01, score: 281
# Scores: (min: 12, avg: 118.35714285714286, max: 314)
#
# Run: 57, exploration: 0.01, score: 158
# Scores: (min: 12, avg: 119.05263157894737, max: 314)
#
# Run: 58, exploration: 0.01, score: 132
# Scores: (min: 12, avg: 119.27586206896552, max: 314)
#
# Run: 59, exploration: 0.01, score: 185
# Scores: (min: 12, avg: 120.38983050847457, max: 314)
#
# Run: 60, exploration: 0.01, score: 170
# Scores: (min: 12, avg: 121.21666666666667, max: 314)
#
# Run: 61, exploration: 0.01, score: 223
# Scores: (min: 12, avg: 122.88524590163935, max: 314)
#
# Run: 62, exploration: 0.01, score: 204
# Scores: (min: 12, avg: 124.19354838709677, max: 314)
#
# Run: 63, exploration: 0.01, score: 174
# Scores: (min: 12, avg: 124.98412698412699, max: 314)
#
# Run: 64, exploration: 0.01, score: 201
# Scores: (min: 12, avg: 126.171875, max: 314)
#
# Run: 65, exploration: 0.01, score: 200
# Scores: (min: 12, avg: 127.3076923076923, max: 314)
#
# Run: 66, exploration: 0.01, score: 464
# Scores: (min: 12, avg: 132.4090909090909, max: 464)
#
# Run: 67, exploration: 0.01, score: 151
# Scores: (min: 12, avg: 132.6865671641791, max: 464)
#
# Run: 68, exploration: 0.01, score: 220
# Scores: (min: 12, avg: 133.97058823529412, max: 464)
#
# Run: 69, exploration: 0.01, score: 183
# Scores: (min: 12, avg: 134.68115942028984, max: 464)
#
# Run: 70, exploration: 0.01, score: 177
# Scores: (min: 12, avg: 135.28571428571428, max: 464)
#
# Run: 71, exploration: 0.01, score: 156
# Scores: (min: 12, avg: 135.57746478873239, max: 464)
#
# Run: 72, exploration: 0.01, score: 178
# Scores: (min: 12, avg: 136.16666666666666, max: 464)
#
# Run: 73, exploration: 0.01, score: 233
# Scores: (min: 12, avg: 137.4931506849315, max: 464)
#
# Run: 74, exploration: 0.01, score: 196
# Scores: (min: 12, avg: 138.28378378378378, max: 464)
#
# Run: 75, exploration: 0.01, score: 182
# Scores: (min: 12, avg: 138.86666666666667, max: 464)
#
# Run: 76, exploration: 0.01, score: 195
# Scores: (min: 12, avg: 139.60526315789474, max: 464)
#
# Run: 77, exploration: 0.01, score: 142
# Scores: (min: 12, avg: 139.63636363636363, max: 464)
#
# Run: 78, exploration: 0.01, score: 145
# Scores: (min: 12, avg: 139.7051282051282, max: 464)
#
# Run: 79, exploration: 0.01, score: 331
# Scores: (min: 12, avg: 142.126582278481, max: 464)
#
# Run: 80, exploration: 0.01, score: 316
# Scores: (min: 12, avg: 144.3, max: 464)
#
# Run: 81, exploration: 0.01, score: 172
# Scores: (min: 12, avg: 144.64197530864197, max: 464)
#
# Run: 82, exploration: 0.01, score: 134
# Scores: (min: 12, avg: 144.5121951219512, max: 464)
#
# Run: 83, exploration: 0.01, score: 194
# Scores: (min: 12, avg: 145.10843373493975, max: 464)
#
# Run: 84, exploration: 0.01, score: 315
# Scores: (min: 12, avg: 147.13095238095238, max: 464)
#
# Run: 85, exploration: 0.01, score: 122
# Scores: (min: 12, avg: 146.83529411764707, max: 464)
#
# Run: 86, exploration: 0.01, score: 121
# Scores: (min: 12, avg: 146.53488372093022, max: 464)
#
# Run: 87, exploration: 0.01, score: 246
# Scores: (min: 12, avg: 147.67816091954023, max: 464)
#
# Run: 88, exploration: 0.01, score: 334
# Scores: (min: 12, avg: 149.79545454545453, max: 464)
#
# Run: 89, exploration: 0.01, score: 137
# Scores: (min: 12, avg: 149.65168539325842, max: 464)
# Run: 90, exploration: 0.01, score: 160
# Scores: (min: 12, avg: 149.76666666666668, max: 464)
#
# Run: 91, exploration: 0.01, score: 216
# Scores: (min: 12, avg: 150.4945054945055, max: 464)
#
# Run: 92, exploration: 0.01, score: 231
# Scores: (min: 12, avg: 151.3695652173913, max: 464)
#
# Run: 93, exploration: 0.01, score: 424
# Scores: (min: 12, avg: 154.30107526881721, max: 464)
#
# Run: 94, exploration: 0.01, score: 153
# Scores: (min: 12, avg: 154.2872340425532, max: 464)
#
# Run: 95, exploration: 0.01, score: 218
# Scores: (min: 12, avg: 154.9578947368421, max: 464)
#
# Run: 96, exploration: 0.01, score: 173
# Scores: (min: 12, avg: 155.14583333333334, max: 464)
#
# Run: 97, exploration: 0.01, score: 210
# Scores: (min: 12, avg: 155.71134020618555, max: 464)
#
# Run: 98, exploration: 0.01, score: 143
# Scores: (min: 12, avg: 155.58163265306123, max: 464)
#
# Run: 99, exploration: 0.01, score: 248
# Scores: (min: 12, avg: 156.5151515151515, max: 464)
#
# Run: 100, exploration: 0.01, score: 204
# Scores: (min: 12, avg: 156.99, max: 464)
#
# Run: 101, exploration: 0.01, score: 382
# Scores: (min: 12, avg: 160.41, max: 464)
#
# Run: 102, exploration: 0.01, score: 173
# Scores: (min: 12, avg: 161.98, max: 464)
#
# Run: 103, exploration: 0.01, score: 216
# Scores: (min: 12, avg: 163.97, max: 464)
#
# Run: 104, exploration: 0.01, score: 172
# Scores: (min: 14, avg: 165.57, max: 464)
#
# Run: 105, exploration: 0.01, score: 301
# Scores: (min: 14, avg: 168.38, max: 464)
#
# Run: 106, exploration: 0.01, score: 211
# Scores: (min: 14, avg: 170.25, max: 464)
#
# Run: 107, exploration: 0.01, score: 161
# Scores: (min: 14, avg: 171.68, max: 464)
#
# Run: 108, exploration: 0.01, score: 159
# Scores: (min: 14, avg: 172.99, max: 464)
#
# Run: 109, exploration: 0.01, score: 126
# Scores: (min: 14, avg: 173.89, max: 464)
#
# Run: 110, exploration: 0.01, score: 328
# Scores: (min: 14, avg: 176.87, max: 464)
#
# Run: 111, exploration: 0.01, score: 285
# Scores: (min: 14, avg: 178.42, max: 464)
#
# Run: 112, exploration: 0.01, score: 168
# Scores: (min: 14, avg: 179.63, max: 464)
#
# Run: 113, exploration: 0.01, score: 145
# Scores: (min: 14, avg: 180.83, max: 464)
#
# Run: 114, exploration: 0.01, score: 210
# Scores: (min: 14, avg: 182.77, max: 464)
#
# Run: 115, exploration: 0.01, score: 367
# Scores: (min: 14, avg: 185.95, max: 464)
#
# Run: 116, exploration: 0.01, score: 232
# Scores: (min: 14, avg: 187.7, max: 464)
#
# Run: 117, exploration: 0.01, score: 347
# Scores: (min: 14, avg: 190.81, max: 464)
#
# Run: 118, exploration: 0.01, score: 251
# Scores: (min: 14, avg: 193.09, max: 464)
#
# Run: 119, exploration: 0.01, score: 382
# Scores: (min: 14, avg: 196.34, max: 464)
#
# Solved in 19 runs, 119 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-e23913c48dc8> in <module>
# ----> 1 cartpole()
#
# <ipython-input-1-bea6327a4fd8> in cartpole()
#      84             if terminal:
#      85                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 86                 score_logger.add_score(step, run)
#      87                 break
#      88             dqn_solver.experience_replay()
#
# U:\Cartpole\Cartpole\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %% [markdown]
# Note: If the code is running properly, you should begin to see output appearing above this code block. It will take several minutes, so it is recommended that you let this code run in the background while completing other work. When the code has finished, it will print output saying, "Solved in _ runs, _ total runs."
#
# You may see an error about not having an exit command. This error does not affect the program's functionality and results from the steps taken to convert the code from Python 2.x to Python 3. Please disregard this error.

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  
  
GAMMA = 0.95  
LEARNING_RATE = 0.001  
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  
  
EXPLORATION_MAX = 0.5  #changed exploration
EXPLORATION_MIN = 0.01  
EXPLORATION_DECAY = 0.995  
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()

# %%
cartpole()
# Out:
# Run: 1, exploration: 1.0, score: 17
# Scores: (min: 17, avg: 17, max: 17)
#
# Run: 2, exploration: 0.8224322824348486, score: 42
# Scores: (min: 17, avg: 29.5, max: 42)
#
# Run: 3, exploration: 0.7861544476842928, score: 10
# Scores: (min: 10, avg: 23, max: 42)
#
# Run: 4, exploration: 0.736559652908221, score: 14
# Scores: (min: 10, avg: 20.75, max: 42)
#
# Run: 5, exploration: 0.7005493475733617, score: 11
# Scores: (min: 10, avg: 18.8, max: 42)
#
# Run: 6, exploration: 0.6563549768288433, score: 14
# Scores: (min: 10, avg: 18, max: 42)
#
# Run: 7, exploration: 0.6118738784280476, score: 15
# Scores: (min: 10, avg: 17.571428571428573, max: 42)
#
# Run: 8, exploration: 0.5848838636585911, score: 10
# Scores: (min: 10, avg: 16.625, max: 42)
#
# Run: 9, exploration: 0.5562889678716474, score: 11
# Scores: (min: 10, avg: 16, max: 42)
#
# Run: 10, exploration: 0.5264466124450268, score: 12
# Scores: (min: 10, avg: 15.6, max: 42)
#
# Run: 11, exploration: 0.500708706245853, score: 11
# Scores: (min: 10, avg: 15.181818181818182, max: 42)
#
# Run: 12, exploration: 0.4484282034609769, score: 23
# Scores: (min: 10, avg: 15.833333333333334, max: 42)
#
# Run: 13, exploration: 0.4286478463299511, score: 10
# Scores: (min: 10, avg: 15.384615384615385, max: 42)
#
# Run: 14, exploration: 0.37816180712868996, score: 26
# Scores: (min: 10, avg: 16.142857142857142, max: 42)
#
# Run: 15, exploration: 0.35253382661792404, score: 15
# Scores: (min: 10, avg: 16.066666666666666, max: 42)
#
# Run: 16, exploration: 0.33698341088258443, score: 10
# Scores: (min: 10, avg: 15.6875, max: 42)
#
# Run: 17, exploration: 0.3173112652388396, score: 13
# Scores: (min: 10, avg: 15.529411764705882, max: 42)
#
# Run: 18, exploration: 0.29729358661854943, score: 14
# Scores: (min: 10, avg: 15.444444444444445, max: 42)
#
# Run: 19, exploration: 0.285607880564032, score: 9
# Scores: (min: 9, avg: 15.105263157894736, max: 42)
#
# Run: 20, exploration: 0.2689348941735696, score: 13
# Scores: (min: 9, avg: 15, max: 42)
#
# Run: 21, exploration: 0.2570720625972084, score: 10
# Scores: (min: 9, avg: 14.761904761904763, max: 42)
#
# Run: 22, exploration: 0.24696734223472733, score: 9
# Scores: (min: 9, avg: 14.5, max: 42)
#
# Run: 23, exploration: 0.23725980767521673, score: 9
# Scores: (min: 9, avg: 14.26086956521739, max: 42)
#
# Run: 24, exploration: 0.22793384675362674, score: 9
# Scores: (min: 9, avg: 14.041666666666666, max: 42)
#
# Run: 25, exploration: 0.2189744609715989, score: 9
# Scores: (min: 9, avg: 13.84, max: 42)
#
# Run: 26, exploration: 0.21036724137609603, score: 9
# Scores: (min: 9, avg: 13.653846153846153, max: 42)
#
# Run: 27, exploration: 0.19808659230739353, score: 13
# Scores: (min: 9, avg: 13.62962962962963, max: 42)
#
# Run: 28, exploration: 0.1903004112552766, score: 9
# Scores: (min: 9, avg: 13.464285714285714, max: 42)
#
# Run: 29, exploration: 0.18190617987607657, score: 10
# Scores: (min: 9, avg: 13.344827586206897, max: 42)
#
# Run: 30, exploration: 0.17388222158237718, score: 10
# Scores: (min: 9, avg: 13.233333333333333, max: 42)
#
# Run: 31, exploration: 0.1662122034722543, score: 10
# Scores: (min: 9, avg: 13.129032258064516, max: 42)
#
# Run: 32, exploration: 0.15967890763313974, score: 9
# Scores: (min: 9, avg: 13, max: 42)
#
# Run: 33, exploration: 0.1534024157688821, score: 9
# Scores: (min: 9, avg: 12.878787878787879, max: 42)
#
# Run: 34, exploration: 0.13946676683816583, score: 20
# Scores: (min: 9, avg: 13.088235294117647, max: 42)
#
# Run: 35, exploration: 0.06542683706543727, score: 152
# Scores: (min: 9, avg: 17.057142857142857, max: 152)
#
# Run: 36, exploration: 0.050162503748802344, score: 54
# Scores: (min: 9, avg: 18.083333333333332, max: 152)
#
# Run: 37, exploration: 0.03461682084029365, score: 75
# Scores: (min: 9, avg: 19.62162162162162, max: 152)
#
# Run: 38, exploration: 0.027765323199097504, score: 45
# Scores: (min: 9, avg: 20.289473684210527, max: 152)
#
# Run: 39, exploration: 0.023297566459620722, score: 36
# Scores: (min: 9, avg: 20.692307692307693, max: 152)
#
# Run: 40, exploration: 0.019745685882295267, score: 34
# Scores: (min: 9, avg: 21.025, max: 152)
#
# Run: 41, exploration: 0.015601164601953134, score: 48
# Scores: (min: 9, avg: 21.682926829268293, max: 152)
#
# Run: 42, exploration: 0.01154893304942575, score: 61
# Scores: (min: 9, avg: 22.61904761904762, max: 152)
#
# Run: 43, exploration: 0.01, score: 33
# Scores: (min: 9, avg: 22.86046511627907, max: 152)
#
# Run: 44, exploration: 0.01, score: 41
# Scores: (min: 9, avg: 23.272727272727273, max: 152)
#
# Run: 45, exploration: 0.01, score: 51
# Scores: (min: 9, avg: 23.88888888888889, max: 152)
#
# Run: 46, exploration: 0.01, score: 38
# Scores: (min: 9, avg: 24.195652173913043, max: 152)
#
# Run: 47, exploration: 0.01, score: 43
# Scores: (min: 9, avg: 24.595744680851062, max: 152)
#
# Run: 48, exploration: 0.01, score: 41
# Scores: (min: 9, avg: 24.9375, max: 152)
#
# Run: 49, exploration: 0.01, score: 48
# Scores: (min: 9, avg: 25.408163265306122, max: 152)
#
# Run: 50, exploration: 0.01, score: 66
# Scores: (min: 9, avg: 26.22, max: 152)
#
# Run: 51, exploration: 0.01, score: 42
# Scores: (min: 9, avg: 26.529411764705884, max: 152)
#
# Run: 52, exploration: 0.01, score: 43
# Scores: (min: 9, avg: 26.846153846153847, max: 152)
#
# Run: 53, exploration: 0.01, score: 40
# Scores: (min: 9, avg: 27.09433962264151, max: 152)
#
# Run: 54, exploration: 0.01, score: 34
# Scores: (min: 9, avg: 27.22222222222222, max: 152)
#
# Run: 55, exploration: 0.01, score: 45
# Scores: (min: 9, avg: 27.545454545454547, max: 152)
#
# Run: 56, exploration: 0.01, score: 40
# Scores: (min: 9, avg: 27.767857142857142, max: 152)
#
# Run: 57, exploration: 0.01, score: 51
# Scores: (min: 9, avg: 28.17543859649123, max: 152)
#
# Run: 58, exploration: 0.01, score: 67
# Scores: (min: 9, avg: 28.844827586206897, max: 152)
#
# Run: 59, exploration: 0.01, score: 63
# Scores: (min: 9, avg: 29.423728813559322, max: 152)
#
# Run: 60, exploration: 0.01, score: 69
# Scores: (min: 9, avg: 30.083333333333332, max: 152)
#
# Run: 61, exploration: 0.01, score: 83
# Scores: (min: 9, avg: 30.950819672131146, max: 152)
#
# Run: 62, exploration: 0.01, score: 94
# Scores: (min: 9, avg: 31.967741935483872, max: 152)
#
# Run: 63, exploration: 0.01, score: 73
# Scores: (min: 9, avg: 32.61904761904762, max: 152)
#
# Run: 64, exploration: 0.01, score: 89
# Scores: (min: 9, avg: 33.5, max: 152)
#
# Run: 65, exploration: 0.01, score: 167
# Scores: (min: 9, avg: 35.55384615384615, max: 167)
#
# Run: 66, exploration: 0.01, score: 281
# Scores: (min: 9, avg: 39.27272727272727, max: 281)
#
# Run: 67, exploration: 0.01, score: 261
# Scores: (min: 9, avg: 42.582089552238806, max: 281)
#
# Run: 68, exploration: 0.01, score: 271
# Scores: (min: 9, avg: 45.94117647058823, max: 281)
#
# Run: 69, exploration: 0.01, score: 395
# Scores: (min: 9, avg: 51, max: 395)
#
# Run: 70, exploration: 0.01, score: 308
# Scores: (min: 9, avg: 54.67142857142857, max: 395)
#
# Run: 71, exploration: 0.01, score: 287
# Scores: (min: 9, avg: 57.943661971830984, max: 395)
#
# Run: 72, exploration: 0.01, score: 319
# Scores: (min: 9, avg: 61.56944444444444, max: 395)
#
# Run: 73, exploration: 0.01, score: 462
# Scores: (min: 9, avg: 67.05479452054794, max: 462)
#
# Run: 74, exploration: 0.01, score: 251
# Scores: (min: 9, avg: 69.54054054054055, max: 462)
#
# Run: 75, exploration: 0.01, score: 333
# Scores: (min: 9, avg: 73.05333333333333, max: 462)
#
# Run: 76, exploration: 0.01, score: 260
# Scores: (min: 9, avg: 75.51315789473684, max: 462)
#
# Run: 77, exploration: 0.01, score: 284
# Scores: (min: 9, avg: 78.22077922077922, max: 462)
#
# Run: 78, exploration: 0.01, score: 317
# Scores: (min: 9, avg: 81.28205128205128, max: 462)
#
# Run: 79, exploration: 0.01, score: 276
# Scores: (min: 9, avg: 83.74683544303798, max: 462)
#
# Run: 80, exploration: 0.01, score: 327
# Scores: (min: 9, avg: 86.7875, max: 462)
#
# Run: 81, exploration: 0.01, score: 307
# Scores: (min: 9, avg: 89.50617283950618, max: 462)
#
# Run: 82, exploration: 0.01, score: 423
# Scores: (min: 9, avg: 93.57317073170732, max: 462)
#
# Run: 83, exploration: 0.01, score: 404
# Scores: (min: 9, avg: 97.3132530120482, max: 462)
#
# Run: 84, exploration: 0.01, score: 353
# Scores: (min: 9, avg: 100.35714285714286, max: 462)
#
# Run: 85, exploration: 0.01, score: 416
# Scores: (min: 9, avg: 104.07058823529412, max: 462)
#
# Run: 86, exploration: 0.01, score: 250
# Scores: (min: 9, avg: 105.76744186046511, max: 462)
#
# Run: 87, exploration: 0.01, score: 448
# Scores: (min: 9, avg: 109.70114942528735, max: 462)
# Run: 88, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 114.13636363636364, max: 500)
#
# Run: 89, exploration: 0.01, score: 209
# Scores: (min: 9, avg: 115.20224719101124, max: 500)
#
# Run: 90, exploration: 0.01, score: 425
# Scores: (min: 9, avg: 118.64444444444445, max: 500)
#
# Run: 91, exploration: 0.01, score: 437
# Scores: (min: 9, avg: 122.14285714285714, max: 500)
#
# Run: 92, exploration: 0.01, score: 424
# Scores: (min: 9, avg: 125.42391304347827, max: 500)
#
# Run: 93, exploration: 0.01, score: 334
# Scores: (min: 9, avg: 127.66666666666667, max: 500)
#
# Run: 94, exploration: 0.01, score: 246
# Scores: (min: 9, avg: 128.9255319148936, max: 500)
#
# Run: 95, exploration: 0.01, score: 231
# Scores: (min: 9, avg: 130, max: 500)
#
# Run: 96, exploration: 0.01, score: 315
# Scores: (min: 9, avg: 131.92708333333334, max: 500)
#
# Run: 97, exploration: 0.01, score: 391
# Scores: (min: 9, avg: 134.5979381443299, max: 500)
#
# Run: 98, exploration: 0.01, score: 315
# Scores: (min: 9, avg: 136.4387755102041, max: 500)
#
# Run: 99, exploration: 0.01, score: 266
# Scores: (min: 9, avg: 137.74747474747474, max: 500)
#
# Run: 100, exploration: 0.01, score: 207
# Scores: (min: 9, avg: 138.44, max: 500)
#
# Run: 101, exploration: 0.01, score: 370
# Scores: (min: 9, avg: 141.97, max: 500)
#
# Run: 102, exploration: 0.01, score: 284
# Scores: (min: 9, avg: 144.39, max: 500)
#
# Run: 103, exploration: 0.01, score: 267
# Scores: (min: 9, avg: 146.96, max: 500)
#
# Run: 104, exploration: 0.01, score: 268
# Scores: (min: 9, avg: 149.5, max: 500)
#
# Run: 105, exploration: 0.01, score: 238
# Scores: (min: 9, avg: 151.77, max: 500)
#
# Run: 106, exploration: 0.01, score: 272
# Scores: (min: 9, avg: 154.35, max: 500)
#
# Run: 107, exploration: 0.01, score: 233
# Scores: (min: 9, avg: 156.53, max: 500)
#
# Run: 108, exploration: 0.01, score: 184
# Scores: (min: 9, avg: 158.27, max: 500)
#
# Run: 109, exploration: 0.01, score: 266
# Scores: (min: 9, avg: 160.82, max: 500)
#
# Run: 110, exploration: 0.01, score: 234
# Scores: (min: 9, avg: 163.04, max: 500)
#
# Run: 111, exploration: 0.01, score: 185
# Scores: (min: 9, avg: 164.78, max: 500)
#
# Run: 112, exploration: 0.01, score: 316
# Scores: (min: 9, avg: 167.71, max: 500)
#
# Run: 113, exploration: 0.01, score: 236
# Scores: (min: 9, avg: 169.97, max: 500)
#
# Run: 114, exploration: 0.01, score: 350
# Scores: (min: 9, avg: 173.21, max: 500)
#
# Run: 115, exploration: 0.01, score: 167
# Scores: (min: 9, avg: 174.73, max: 500)
#
# Run: 116, exploration: 0.01, score: 190
# Scores: (min: 9, avg: 176.53, max: 500)
#
# Run: 117, exploration: 0.01, score: 212
# Scores: (min: 9, avg: 178.52, max: 500)
#
# Run: 118, exploration: 0.01, score: 316
# Scores: (min: 9, avg: 181.54, max: 500)
#
# Run: 119, exploration: 0.01, score: 228
# Scores: (min: 9, avg: 183.73, max: 500)
#
# Run: 120, exploration: 0.01, score: 214
# Scores: (min: 9, avg: 185.74, max: 500)
#
# Run: 121, exploration: 0.01, score: 218
# Scores: (min: 9, avg: 187.82, max: 500)
#
# Run: 122, exploration: 0.01, score: 236
# Scores: (min: 9, avg: 190.09, max: 500)
#
# Run: 123, exploration: 0.01, score: 307
# Scores: (min: 9, avg: 193.07, max: 500)
#
# Run: 124, exploration: 0.01, score: 292
# Scores: (min: 9, avg: 195.9, max: 500)
#
# Solved in 24 runs, 124 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-e23913c48dc8> in <module>
# ----> 1 cartpole()
#
# <ipython-input-1-bea6327a4fd8> in cartpole()
#      84             if terminal:
#      85                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 86                 score_logger.add_score(step, run)
#      87                 break
#      88             dqn_solver.experience_replay()
#
# U:\Cartpole\Cartpole\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  
  
GAMMA = 0.5   #changeing Gamma this time  
LEARNING_RATE = 0.001  
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  
  
EXPLORATION_MAX = 1.0 
EXPLORATION_MIN = 0.01  
EXPLORATION_DECAY = 0.995  
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()

# %%
cartpole()
# Out:
# Run: 1, exploration: 0.9229311239742362, score: 36
# Scores: (min: 36, avg: 36, max: 36)
#
# Run: 2, exploration: 0.8348931673187264, score: 21
# Scores: (min: 21, avg: 28.5, max: 36)
#
# Run: 3, exploration: 0.7628626641409962, score: 19
# Scores: (min: 19, avg: 25.333333333333332, max: 36)
#
# Run: 4, exploration: 0.7005493475733617, score: 18
# Scores: (min: 18, avg: 23.5, max: 36)
#
# Run: 5, exploration: 0.6596532430440636, score: 13
# Scores: (min: 13, avg: 21.4, max: 36)
#
# Run: 6, exploration: 0.6305556603555866, score: 10
# Scores: (min: 10, avg: 19.5, max: 36)
#
# Run: 7, exploration: 0.5907768628656763, score: 14
# Scores: (min: 10, avg: 18.714285714285715, max: 36)
#
# Run: 8, exploration: 0.5618938591163328, score: 11
# Scores: (min: 10, avg: 17.75, max: 36)
#
# Run: 9, exploration: 0.5290920728090721, score: 13
# Scores: (min: 10, avg: 17.22222222222222, max: 36)
#
# Run: 10, exploration: 0.4858739637363176, score: 18
# Scores: (min: 10, avg: 17.3, max: 36)
#
# Run: 11, exploration: 0.45522245551230495, score: 14
# Scores: (min: 10, avg: 17, max: 36)
#
# Run: 12, exploration: 0.43952667968844233, score: 8
# Scores: (min: 8, avg: 16.25, max: 36)
#
# Run: 13, exploration: 0.4159480862733536, score: 12
# Scores: (min: 8, avg: 15.923076923076923, max: 36)
#
# Run: 14, exploration: 0.39561243860243744, score: 11
# Scores: (min: 8, avg: 15.571428571428571, max: 36)
#
# Run: 15, exploration: 0.37627099809304654, score: 11
# Scores: (min: 8, avg: 15.266666666666667, max: 36)
#
# Run: 16, exploration: 0.3578751580867638, score: 11
# Scores: (min: 8, avg: 15, max: 36)
#
# Run: 17, exploration: 0.33698341088258443, score: 13
# Scores: (min: 8, avg: 14.882352941176471, max: 36)
#
# Run: 18, exploration: 0.32050833588933575, score: 11
# Scores: (min: 8, avg: 14.666666666666666, max: 36)
#
# Run: 19, exploration: 0.3063705780533402, score: 10
# Scores: (min: 8, avg: 14.421052631578947, max: 36)
#
# Run: 20, exploration: 0.2913921604631864, score: 11
# Scores: (min: 8, avg: 14.25, max: 36)
#
# Run: 21, exploration: 0.27714603575484437, score: 11
# Scores: (min: 8, avg: 14.095238095238095, max: 36)
#
# Run: 22, exploration: 0.2178795886667409, score: 49
# Scores: (min: 8, avg: 15.681818181818182, max: 49)
#
# Run: 23, exploration: 0.138769433003975, score: 91
# Scores: (min: 8, avg: 18.956521739130434, max: 91)
#
# Run: 24, exploration: 0.07836551983717477, score: 115
# Scores: (min: 8, avg: 22.958333333333332, max: 115)
#
# Run: 25, exploration: 0.017595559502304726, score: 299
# Scores: (min: 8, avg: 34, max: 299)
#
# Run: 26, exploration: 0.01, score: 173
# Scores: (min: 8, avg: 39.34615384615385, max: 299)
#
# Run: 27, exploration: 0.01, score: 144
# Scores: (min: 8, avg: 43.22222222222222, max: 299)
#
# Run: 28, exploration: 0.01, score: 116
# Scores: (min: 8, avg: 45.82142857142857, max: 299)
#
# Run: 29, exploration: 0.01, score: 130
# Scores: (min: 8, avg: 48.724137931034484, max: 299)
#
# Run: 30, exploration: 0.01, score: 122
# Scores: (min: 8, avg: 51.166666666666664, max: 299)
#
# Run: 31, exploration: 0.01, score: 138
# Scores: (min: 8, avg: 53.96774193548387, max: 299)
#
# Run: 32, exploration: 0.01, score: 190
# Scores: (min: 8, avg: 58.21875, max: 299)
#
# Run: 33, exploration: 0.01, score: 147
# Scores: (min: 8, avg: 60.90909090909091, max: 299)
#
# Run: 34, exploration: 0.01, score: 218
# Scores: (min: 8, avg: 65.52941176470588, max: 299)
#
# Run: 35, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 77.94285714285714, max: 500)
#
# Run: 36, exploration: 0.01, score: 159
# Scores: (min: 8, avg: 80.19444444444444, max: 500)
#
# Run: 37, exploration: 0.01, score: 132
# Scores: (min: 8, avg: 81.5945945945946, max: 500)
#
# Run: 38, exploration: 0.01, score: 87
# Scores: (min: 8, avg: 81.73684210526316, max: 500)
#
# Run: 39, exploration: 0.01, score: 88
# Scores: (min: 8, avg: 81.8974358974359, max: 500)
#
# Run: 40, exploration: 0.01, score: 206
# Scores: (min: 8, avg: 85, max: 500)
#
# Run: 41, exploration: 0.01, score: 132
# Scores: (min: 8, avg: 86.14634146341463, max: 500)
#
# Run: 42, exploration: 0.01, score: 95
# Scores: (min: 8, avg: 86.35714285714286, max: 500)
#
# Run: 43, exploration: 0.01, score: 310
# Scores: (min: 8, avg: 91.55813953488372, max: 500)
#
# Run: 44, exploration: 0.01, score: 346
# Scores: (min: 8, avg: 97.3409090909091, max: 500)
#
# Run: 45, exploration: 0.01, score: 245
# Scores: (min: 8, avg: 100.62222222222222, max: 500)
#
# Run: 46, exploration: 0.01, score: 104
# Scores: (min: 8, avg: 100.69565217391305, max: 500)
#
# Run: 47, exploration: 0.01, score: 235
# Scores: (min: 8, avg: 103.55319148936171, max: 500)
#
# Run: 48, exploration: 0.01, score: 486
# Scores: (min: 8, avg: 111.52083333333333, max: 500)
#
# Run: 49, exploration: 0.01, score: 380
# Scores: (min: 8, avg: 117, max: 500)
#
# Run: 50, exploration: 0.01, score: 259
# Scores: (min: 8, avg: 119.84, max: 500)
#
# Run: 51, exploration: 0.01, score: 272
# Scores: (min: 8, avg: 122.82352941176471, max: 500)
#
# Run: 52, exploration: 0.01, score: 461
# Scores: (min: 8, avg: 129.32692307692307, max: 500)
#
# Run: 53, exploration: 0.01, score: 465
# Scores: (min: 8, avg: 135.66037735849056, max: 500)
#
# Run: 54, exploration: 0.01, score: 303
# Scores: (min: 8, avg: 138.75925925925927, max: 500)
#
# Run: 55, exploration: 0.01, score: 390
# Scores: (min: 8, avg: 143.3272727272727, max: 500)
#
# Run: 56, exploration: 0.01, score: 332
# Scores: (min: 8, avg: 146.69642857142858, max: 500)
#
# Run: 57, exploration: 0.01, score: 217
# Scores: (min: 8, avg: 147.9298245614035, max: 500)
#
# Run: 58, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 154, max: 500)
#
# Run: 59, exploration: 0.01, score: 191
# Scores: (min: 8, avg: 154.6271186440678, max: 500)
#
# Run: 60, exploration: 0.01, score: 346
# Scores: (min: 8, avg: 157.81666666666666, max: 500)
#
# Run: 61, exploration: 0.01, score: 321
# Scores: (min: 8, avg: 160.49180327868854, max: 500)
#
# Run: 62, exploration: 0.01, score: 491
# Scores: (min: 8, avg: 165.82258064516128, max: 500)
#
# Run: 63, exploration: 0.01, score: 159
# Scores: (min: 8, avg: 165.71428571428572, max: 500)
#
# Run: 64, exploration: 0.01, score: 271
# Scores: (min: 8, avg: 167.359375, max: 500)
#
# Run: 65, exploration: 0.01, score: 452
# Scores: (min: 8, avg: 171.73846153846154, max: 500)
#
# Run: 66, exploration: 0.01, score: 219
# Scores: (min: 8, avg: 172.45454545454547, max: 500)
#
# Run: 67, exploration: 0.01, score: 310
# Scores: (min: 8, avg: 174.50746268656715, max: 500)
#
# Run: 68, exploration: 0.01, score: 209
# Scores: (min: 8, avg: 175.01470588235293, max: 500)
#
# Run: 69, exploration: 0.01, score: 329
# Scores: (min: 8, avg: 177.2463768115942, max: 500)
#
# Run: 70, exploration: 0.01, score: 264
# Scores: (min: 8, avg: 178.4857142857143, max: 500)
#
# Run: 71, exploration: 0.01, score: 374
# Scores: (min: 8, avg: 181.2394366197183, max: 500)
#
# Run: 72, exploration: 0.01, score: 320
# Scores: (min: 8, avg: 183.16666666666666, max: 500)
#
# Run: 73, exploration: 0.01, score: 371
# Scores: (min: 8, avg: 185.73972602739727, max: 500)
#
# Run: 74, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 183.3918918918919, max: 500)
#
# Run: 75, exploration: 0.01, score: 224
# Scores: (min: 8, avg: 183.93333333333334, max: 500)
#
# Run: 76, exploration: 0.01, score: 235
# Scores: (min: 8, avg: 184.60526315789474, max: 500)
#
# Run: 77, exploration: 0.01, score: 144
# Scores: (min: 8, avg: 184.07792207792207, max: 500)
#
# Run: 78, exploration: 0.01, score: 212
# Scores: (min: 8, avg: 184.43589743589743, max: 500)
#
# Run: 79, exploration: 0.01, score: 294
# Scores: (min: 8, avg: 185.8227848101266, max: 500)
#
# Run: 80, exploration: 0.01, score: 157
# Scores: (min: 8, avg: 185.4625, max: 500)
#
# Run: 81, exploration: 0.01, score: 480
# Scores: (min: 8, avg: 189.09876543209876, max: 500)
#
# Run: 82, exploration: 0.01, score: 425
# Scores: (min: 8, avg: 191.97560975609755, max: 500)
#
# Run: 83, exploration: 0.01, score: 179
# Scores: (min: 8, avg: 191.81927710843374, max: 500)
#
# Run: 84, exploration: 0.01, score: 263
# Scores: (min: 8, avg: 192.66666666666666, max: 500)
#
# Run: 85, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 196.28235294117647, max: 500)
#
# Run: 86, exploration: 0.01, score: 397
# Scores: (min: 8, avg: 198.61627906976744, max: 500)
#
# Run: 87, exploration: 0.01, score: 280
# Scores: (min: 8, avg: 199.55172413793105, max: 500)
#
# Run: 88, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 202.9659090909091, max: 500)
#
# Run: 89, exploration: 0.01, score: 410
# Scores: (min: 8, avg: 205.2921348314607, max: 500)
# Run: 90, exploration: 0.01, score: 176
# Scores: (min: 8, avg: 204.96666666666667, max: 500)
#
# Run: 91, exploration: 0.01, score: 326
# Scores: (min: 8, avg: 206.2967032967033, max: 500)
#
# Run: 92, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 209.4891304347826, max: 500)
#
# Run: 93, exploration: 0.01, score: 55
# Scores: (min: 8, avg: 207.8279569892473, max: 500)
#
# Run: 94, exploration: 0.01, score: 212
# Scores: (min: 8, avg: 207.87234042553192, max: 500)
#
# Run: 95, exploration: 0.01, score: 355
# Scores: (min: 8, avg: 209.42105263157896, max: 500)
#
# Run: 96, exploration: 0.01, score: 151
# Scores: (min: 8, avg: 208.8125, max: 500)
#
# Run: 97, exploration: 0.01, score: 275
# Scores: (min: 8, avg: 209.49484536082474, max: 500)
#
# Run: 98, exploration: 0.01, score: 207
# Scores: (min: 8, avg: 209.46938775510205, max: 500)
#
# Run: 99, exploration: 0.01, score: 269
# Scores: (min: 8, avg: 210.07070707070707, max: 500)
#
# Run: 100, exploration: 0.01, score: 304
# Scores: (min: 8, avg: 211.01, max: 500)
#
# Solved in 0 runs, 100 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-e23913c48dc8> in <module>
# ----> 1 cartpole()
#
# <ipython-input-1-bea6327a4fd8> in cartpole()
#      84             if terminal:
#      85                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 86                 score_logger.add_score(step, run)
#      87                 break
#      88             dqn_solver.experience_replay()
#
# U:\Cartpole\Cartpole\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  
  
GAMMA = 0.95   
LEARNING_RATE = 0.0001  #changeing Learning rate this time  
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  
  
EXPLORATION_MAX = 1.0 
EXPLORATION_MIN = 0.01  
EXPLORATION_DECAY = 0.995  
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()
# Out:
# Using TensorFlow backend.

# %%
cartpole()
# Out:
# Run: 1, exploration: 1.0, score: 17
# Scores: (min: 17, avg: 17, max: 17)
#
# Run: 2, exploration: 0.8475428503023453, score: 36
# Scores: (min: 17, avg: 26.5, max: 36)
#
# Run: 3, exploration: 0.7705488893118823, score: 20
# Scores: (min: 17, avg: 24.333333333333332, max: 36)
#
# Run: 4, exploration: 0.7183288830986236, score: 15
# Scores: (min: 15, avg: 22, max: 36)
#
# Run: 5, exploration: 0.6596532430440636, score: 18
# Scores: (min: 15, avg: 21.2, max: 36)
#
# Run: 6, exploration: 0.6180388156137953, score: 14
# Scores: (min: 14, avg: 20, max: 36)
#
# Run: 7, exploration: 0.567555222460375, score: 18
# Scores: (min: 14, avg: 19.714285714285715, max: 36)
#
# Run: 8, exploration: 0.5425201222922789, score: 10
# Scores: (min: 10, avg: 18.5, max: 36)
#
# Run: 9, exploration: 0.510849320360386, score: 13
# Scores: (min: 10, avg: 17.88888888888889, max: 36)
#
# Run: 10, exploration: 0.4883155414435353, score: 10
# Scores: (min: 10, avg: 17.1, max: 36)
#
# Run: 11, exploration: 0.457510005540005, score: 14
# Scores: (min: 10, avg: 16.818181818181817, max: 36)
#
# Run: 12, exploration: 0.43296668905325736, score: 12
# Scores: (min: 10, avg: 16.416666666666668, max: 36)
#
# Run: 13, exploration: 0.40769130904675194, score: 13
# Scores: (min: 10, avg: 16.153846153846153, max: 36)
#
# Run: 14, exploration: 0.3897078735047413, score: 10
# Scores: (min: 10, avg: 15.714285714285714, max: 36)
#
# Run: 15, exploration: 0.3706551064126331, score: 11
# Scores: (min: 10, avg: 15.4, max: 36)
#
# Run: 16, exploration: 0.3543053533848483, score: 10
# Scores: (min: 10, avg: 15.0625, max: 36)
#
# Run: 17, exploration: 0.3420891339682016, score: 8
# Scores: (min: 8, avg: 14.647058823529411, max: 36)
#
# Run: 18, exploration: 0.326999438029567, score: 10
# Scores: (min: 8, avg: 14.38888888888889, max: 36)
#
# Run: 19, exploration: 0.3125753549412418, score: 10
# Scores: (min: 8, avg: 14.157894736842104, max: 36)
#
# Run: 20, exploration: 0.30028896908517405, score: 9
# Scores: (min: 8, avg: 13.9, max: 36)
#
# Run: 21, exploration: 0.28704309604425327, score: 10
# Scores: (min: 8, avg: 13.714285714285714, max: 36)
#
# Run: 22, exploration: 0.2757603055760701, score: 9
# Scores: (min: 8, avg: 13.5, max: 36)
#
# Run: 23, exploration: 0.2609670281126685, score: 12
# Scores: (min: 8, avg: 13.434782608695652, max: 36)
#
# Run: 24, exploration: 0.2494556624678441, score: 10
# Scores: (min: 8, avg: 13.291666666666666, max: 36)
#
# Run: 25, exploration: 0.2408545925762412, score: 8
# Scores: (min: 8, avg: 13.08, max: 36)
#
# Run: 26, exploration: 0.22793384675362674, score: 12
# Scores: (min: 8, avg: 13.038461538461538, max: 36)
#
# Run: 27, exploration: 0.2178795886667409, score: 10
# Scores: (min: 8, avg: 12.925925925925926, max: 36)
#
# Run: 28, exploration: 0.20826882814336947, score: 10
# Scores: (min: 8, avg: 12.821428571428571, max: 36)
#
# Run: 29, exploration: 0.19908200231898848, score: 10
# Scores: (min: 8, avg: 12.724137931034482, max: 36)
#
# Run: 30, exploration: 0.1903004112552766, score: 10
# Scores: (min: 8, avg: 12.633333333333333, max: 36)
#
# Run: 31, exploration: 0.18099664897669618, score: 11
# Scores: (min: 8, avg: 12.580645161290322, max: 36)
#
# Run: 32, exploration: 0.17214774642209296, score: 11
# Scores: (min: 8, avg: 12.53125, max: 36)
#
# Run: 33, exploration: 0.16373146555890544, score: 11
# Scores: (min: 8, avg: 12.484848484848484, max: 36)
#
# Run: 34, exploration: 0.1549480222912372, score: 12
# Scores: (min: 8, avg: 12.470588235294118, max: 36)
#
# Run: 35, exploration: 0.14811319969530845, score: 10
# Scores: (min: 8, avg: 12.4, max: 36)
#
# Run: 36, exploration: 0.14016760486247823, score: 12
# Scores: (min: 8, avg: 12.38888888888889, max: 36)
#
# Run: 37, exploration: 0.13398475271138335, score: 10
# Scores: (min: 8, avg: 12.324324324324325, max: 36)
#
# Run: 38, exploration: 0.12679708435358925, score: 12
# Scores: (min: 8, avg: 12.31578947368421, max: 36)
#
# Run: 39, exploration: 0.11820406108847166, score: 15
# Scores: (min: 8, avg: 12.384615384615385, max: 36)
#
# Run: 40, exploration: 0.11074712159185099, score: 14
# Scores: (min: 8, avg: 12.425, max: 36)
#
# Run: 41, exploration: 0.10480604571960442, score: 12
# Scores: (min: 8, avg: 12.414634146341463, max: 36)
#
# Run: 42, exploration: 0.09868776295209031, score: 13
# Scores: (min: 8, avg: 12.428571428571429, max: 36)
#
# Run: 43, exploration: 0.0906265979439563, score: 18
# Scores: (min: 8, avg: 12.55813953488372, max: 36)
#
# Run: 44, exploration: 0.08364210790237678, score: 17
# Scores: (min: 8, avg: 12.659090909090908, max: 36)
#
# Run: 45, exploration: 0.07642587550895225, score: 19
# Scores: (min: 8, avg: 12.8, max: 36)
#
# Run: 46, exploration: 0.0708902705368767, score: 16
# Scores: (min: 8, avg: 12.869565217391305, max: 36)
#
# Run: 47, exploration: 0.06542683706543727, score: 17
# Scores: (min: 8, avg: 12.957446808510639, max: 36)
#
# Run: 48, exploration: 0.06129936495526111, score: 14
# Scores: (min: 8, avg: 12.979166666666666, max: 36)
#
# Run: 49, exploration: 0.0554520479727078, score: 21
# Scores: (min: 8, avg: 13.142857142857142, max: 36)
#
# Run: 50, exploration: 0.04892091923449087, score: 26
# Scores: (min: 8, avg: 13.4, max: 36)
#
# Run: 51, exploration: 0.04084374120782771, score: 37
# Scores: (min: 8, avg: 13.862745098039216, max: 37)
#
# Run: 52, exploration: 0.019844910434467605, score: 145
# Scores: (min: 8, avg: 16.384615384615383, max: 145)
#
# Run: 53, exploration: 0.016735314893855303, score: 35
# Scores: (min: 8, avg: 16.735849056603772, max: 145)
#
# Run: 54, exploration: 0.015917127532080494, score: 11
# Scores: (min: 8, avg: 16.62962962962963, max: 145)
#
# Run: 55, exploration: 0.01529147369377279, score: 9
# Scores: (min: 8, avg: 16.490909090909092, max: 145)
#
# Run: 56, exploration: 0.014690412403624311, score: 9
# Scores: (min: 8, avg: 16.357142857142858, max: 145)
#
# Run: 57, exploration: 0.014042412118399107, score: 10
# Scores: (min: 8, avg: 16.24561403508772, max: 145)
#
# Run: 58, exploration: 0.013558238831322046, score: 8
# Scores: (min: 8, avg: 16.103448275862068, max: 145)
#
# Run: 59, exploration: 0.012513320603703188, score: 17
# Scores: (min: 8, avg: 16.11864406779661, max: 145)
#
# Run: 60, exploration: 0.011961352755726806, score: 10
# Scores: (min: 8, avg: 16.016666666666666, max: 145)
#
# Run: 61, exploration: 0.011491188384178622, score: 9
# Scores: (min: 8, avg: 15.901639344262295, max: 145)
#
# Run: 62, exploration: 0.011039504743095268, score: 9
# Scores: (min: 8, avg: 15.790322580645162, max: 145)
#
# Run: 63, exploration: 0.010605575411209664, score: 9
# Scores: (min: 8, avg: 15.682539682539682, max: 145)
#
# Run: 64, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 15.765625, max: 145)
#
# Run: 65, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 15.876923076923077, max: 145)
#
# Run: 66, exploration: 0.01, score: 34
# Scores: (min: 8, avg: 16.151515151515152, max: 145)
#
# Run: 67, exploration: 0.01, score: 38
# Scores: (min: 8, avg: 16.47761194029851, max: 145)
#
# Run: 68, exploration: 0.01, score: 32
# Scores: (min: 8, avg: 16.705882352941178, max: 145)
#
# Run: 69, exploration: 0.01, score: 57
# Scores: (min: 8, avg: 17.28985507246377, max: 145)
#
# Run: 70, exploration: 0.01, score: 52
# Scores: (min: 8, avg: 17.785714285714285, max: 145)
#
# Run: 71, exploration: 0.01, score: 34
# Scores: (min: 8, avg: 18.014084507042252, max: 145)
#
# Run: 72, exploration: 0.01, score: 94
# Scores: (min: 8, avg: 19.069444444444443, max: 145)
#
# Run: 73, exploration: 0.01, score: 100
# Scores: (min: 8, avg: 20.17808219178082, max: 145)
#
# Run: 74, exploration: 0.01, score: 36
# Scores: (min: 8, avg: 20.39189189189189, max: 145)
#
# Run: 75, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 20.373333333333335, max: 145)
#
# Run: 76, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 20.223684210526315, max: 145)
#
# Run: 77, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 20.07792207792208, max: 145)
#
# Run: 78, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 19.987179487179485, max: 145)
#
# Run: 79, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 20.075949367088608, max: 145)
#
# Run: 80, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 20.0125, max: 145)
#
# Run: 81, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 19.925925925925927, max: 145)
#
# Run: 82, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 20, max: 145)
#
# Run: 83, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 19.867469879518072, max: 145)
#
# Run: 84, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 19.75, max: 145)
# Run: 85, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 19.83529411764706, max: 145)
#
# Run: 86, exploration: 0.01, score: 39
# Scores: (min: 8, avg: 20.058139534883722, max: 145)
#
# Run: 87, exploration: 0.01, score: 51
# Scores: (min: 8, avg: 20.413793103448278, max: 145)
#
# Run: 88, exploration: 0.01, score: 70
# Scores: (min: 8, avg: 20.977272727272727, max: 145)
#
# Run: 89, exploration: 0.01, score: 38
# Scores: (min: 8, avg: 21.168539325842698, max: 145)
#
# Run: 90, exploration: 0.01, score: 80
# Scores: (min: 8, avg: 21.822222222222223, max: 145)
#
# Run: 91, exploration: 0.01, score: 99
# Scores: (min: 8, avg: 22.67032967032967, max: 145)
#
# Run: 92, exploration: 0.01, score: 57
# Scores: (min: 8, avg: 23.043478260869566, max: 145)
#
# Run: 93, exploration: 0.01, score: 63
# Scores: (min: 8, avg: 23.473118279569892, max: 145)
#
# Run: 94, exploration: 0.01, score: 105
# Scores: (min: 8, avg: 24.340425531914892, max: 145)
#
# Run: 95, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 24.294736842105262, max: 145)
#
# Run: 96, exploration: 0.01, score: 56
# Scores: (min: 8, avg: 24.625, max: 145)
#
# Run: 97, exploration: 0.01, score: 63
# Scores: (min: 8, avg: 25.02061855670103, max: 145)
#
# Run: 98, exploration: 0.01, score: 61
# Scores: (min: 8, avg: 25.387755102040817, max: 145)
#
# Run: 99, exploration: 0.01, score: 41
# Scores: (min: 8, avg: 25.545454545454547, max: 145)
#
# Run: 100, exploration: 0.01, score: 60
# Scores: (min: 8, avg: 25.89, max: 145)
#
# Run: 101, exploration: 0.01, score: 78
# Scores: (min: 8, avg: 26.5, max: 145)
#
# Run: 102, exploration: 0.01, score: 161
# Scores: (min: 8, avg: 27.75, max: 161)
#
# Run: 103, exploration: 0.01, score: 61
# Scores: (min: 8, avg: 28.16, max: 161)
#
# Run: 104, exploration: 0.01, score: 35
# Scores: (min: 8, avg: 28.36, max: 161)
#
# Run: 105, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 28.45, max: 161)
#
# Run: 106, exploration: 0.01, score: 69
# Scores: (min: 8, avg: 29, max: 161)
#
# Run: 107, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 29.13, max: 161)
#
# Run: 108, exploration: 0.01, score: 135
# Scores: (min: 8, avg: 30.38, max: 161)
#
# Run: 109, exploration: 0.01, score: 72
# Scores: (min: 8, avg: 30.97, max: 161)
#
# Run: 110, exploration: 0.01, score: 54
# Scores: (min: 8, avg: 31.41, max: 161)
#
# Run: 111, exploration: 0.01, score: 80
# Scores: (min: 8, avg: 32.07, max: 161)
#
# Run: 112, exploration: 0.01, score: 50
# Scores: (min: 8, avg: 32.45, max: 161)
#
# Run: 113, exploration: 0.01, score: 50
# Scores: (min: 8, avg: 32.82, max: 161)
#
# Run: 114, exploration: 0.01, score: 83
# Scores: (min: 8, avg: 33.55, max: 161)
#
# Run: 115, exploration: 0.01, score: 48
# Scores: (min: 8, avg: 33.92, max: 161)
#
# Run: 116, exploration: 0.01, score: 60
# Scores: (min: 8, avg: 34.42, max: 161)
#
# Run: 117, exploration: 0.01, score: 75
# Scores: (min: 8, avg: 35.09, max: 161)
#
# Run: 118, exploration: 0.01, score: 48
# Scores: (min: 8, avg: 35.47, max: 161)
#
# Run: 119, exploration: 0.01, score: 281
# Scores: (min: 8, avg: 38.18, max: 281)
#
# Run: 120, exploration: 0.01, score: 82
# Scores: (min: 8, avg: 38.91, max: 281)
#
# Run: 121, exploration: 0.01, score: 111
# Scores: (min: 8, avg: 39.92, max: 281)
#
# Run: 122, exploration: 0.01, score: 137
# Scores: (min: 8, avg: 41.2, max: 281)
#
# Run: 123, exploration: 0.01, score: 107
# Scores: (min: 8, avg: 42.15, max: 281)
#
# Run: 124, exploration: 0.01, score: 98
# Scores: (min: 8, avg: 43.03, max: 281)
#
# Run: 125, exploration: 0.01, score: 126
# Scores: (min: 8, avg: 44.21, max: 281)
#
# Run: 126, exploration: 0.01, score: 118
# Scores: (min: 8, avg: 45.27, max: 281)
#
# Run: 127, exploration: 0.01, score: 152
# Scores: (min: 8, avg: 46.69, max: 281)
#
# Run: 128, exploration: 0.01, score: 186
# Scores: (min: 8, avg: 48.45, max: 281)
#
# Run: 129, exploration: 0.01, score: 358
# Scores: (min: 8, avg: 51.93, max: 358)
#
# Run: 130, exploration: 0.01, score: 452
# Scores: (min: 8, avg: 56.35, max: 452)
#
# Run: 131, exploration: 0.01, score: 158
# Scores: (min: 8, avg: 57.82, max: 452)
#
# Run: 132, exploration: 0.01, score: 251
# Scores: (min: 8, avg: 60.22, max: 452)
#
# Run: 133, exploration: 0.01, score: 451
# Scores: (min: 8, avg: 64.62, max: 452)
#
# Run: 134, exploration: 0.01, score: 478
# Scores: (min: 8, avg: 69.28, max: 478)
#
# Run: 135, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 74.18, max: 500)
#
# Run: 136, exploration: 0.01, score: 436
# Scores: (min: 8, avg: 78.42, max: 500)
#
# Run: 137, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 83.32, max: 500)
#
# Run: 138, exploration: 0.01, score: 277
# Scores: (min: 8, avg: 85.97, max: 500)
#
# Run: 139, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 90.82, max: 500)
#
# Run: 140, exploration: 0.01, score: 284
# Scores: (min: 8, avg: 93.52, max: 500)
#
# Run: 141, exploration: 0.01, score: 411
# Scores: (min: 8, avg: 97.51, max: 500)
#
# Run: 142, exploration: 0.01, score: 260
# Scores: (min: 8, avg: 99.98, max: 500)
#
# Run: 143, exploration: 0.01, score: 270
# Scores: (min: 8, avg: 102.5, max: 500)
#
# Run: 144, exploration: 0.01, score: 334
# Scores: (min: 8, avg: 105.67, max: 500)
#
# Run: 145, exploration: 0.01, score: 340
# Scores: (min: 8, avg: 108.88, max: 500)
#
# Run: 146, exploration: 0.01, score: 378
# Scores: (min: 8, avg: 112.5, max: 500)
#
# Run: 147, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 117.33, max: 500)
#
# Run: 148, exploration: 0.01, score: 451
# Scores: (min: 8, avg: 121.7, max: 500)
#
# Run: 149, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 126.49, max: 500)
#
# Run: 150, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 131.23, max: 500)
#
# Run: 151, exploration: 0.01, score: 251
# Scores: (min: 8, avg: 133.37, max: 500)
#
# Run: 152, exploration: 0.01, score: 291
# Scores: (min: 8, avg: 134.83, max: 500)
#
# Run: 153, exploration: 0.01, score: 332
# Scores: (min: 8, avg: 137.8, max: 500)
#
# Run: 154, exploration: 0.01, score: 270
# Scores: (min: 8, avg: 140.39, max: 500)
#
# Run: 155, exploration: 0.01, score: 313
# Scores: (min: 8, avg: 143.43, max: 500)
#
# Run: 156, exploration: 0.01, score: 248
# Scores: (min: 8, avg: 145.82, max: 500)
#
# Run: 157, exploration: 0.01, score: 212
# Scores: (min: 8, avg: 147.84, max: 500)
#
# Run: 158, exploration: 0.01, score: 229
# Scores: (min: 9, avg: 150.05, max: 500)
#
# Run: 159, exploration: 0.01, score: 310
# Scores: (min: 9, avg: 152.98, max: 500)
#
# Run: 160, exploration: 0.01, score: 259
# Scores: (min: 9, avg: 155.47, max: 500)
#
# Run: 161, exploration: 0.01, score: 222
# Scores: (min: 9, avg: 157.6, max: 500)
#
# Run: 162, exploration: 0.01, score: 337
# Scores: (min: 9, avg: 160.88, max: 500)
#
# Run: 163, exploration: 0.01, score: 349
# Scores: (min: 9, avg: 164.28, max: 500)
#
# Run: 164, exploration: 0.01, score: 379
# Scores: (min: 9, avg: 167.86, max: 500)
#
# Run: 165, exploration: 0.01, score: 299
# Scores: (min: 9, avg: 170.62, max: 500)
#
# Run: 166, exploration: 0.01, score: 332
# Scores: (min: 9, avg: 173.6, max: 500)
#
# Run: 167, exploration: 0.01, score: 304
# Scores: (min: 9, avg: 176.26, max: 500)
#
# Run: 168, exploration: 0.01, score: 331
# Scores: (min: 9, avg: 179.25, max: 500)
#
# Run: 169, exploration: 0.01, score: 245
# Scores: (min: 9, avg: 181.13, max: 500)
#
# Run: 170, exploration: 0.01, score: 374
# Scores: (min: 9, avg: 184.35, max: 500)
#
# Run: 171, exploration: 0.01, score: 205
# Scores: (min: 9, avg: 186.06, max: 500)
#
# Run: 172, exploration: 0.01, score: 241
# Scores: (min: 9, avg: 187.53, max: 500)
#
# Run: 173, exploration: 0.01, score: 303
# Scores: (min: 9, avg: 189.56, max: 500)
#
# Run: 174, exploration: 0.01, score: 230
# Scores: (min: 9, avg: 191.5, max: 500)
#
# Run: 175, exploration: 0.01, score: 225
# Scores: (min: 9, avg: 193.56, max: 500)
#
# Run: 176, exploration: 0.01, score: 213
# Scores: (min: 9, avg: 195.6, max: 500)
#
# Solved in 76 runs, 176 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-e23913c48dc8> in <module>
# ----> 1 cartpole()
#
# <ipython-input-2-ac24961f6e8e> in cartpole()
#      84             if terminal:
#      85                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 86                 score_logger.add_score(step, run)
#      87                 break
#      88             dqn_solver.experience_replay()
#
# U:\Cartpole\Cartpole\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %% [markdown]
# What is the goal of the agent in this case?
#         The goal of this agent is to balance a pole that is attached to a cart that can move side to side. The agent iterates along until it finds the best way to balance the pole.
#
# What are the various state values?
#     The state values both start off at 17. Then, the min drops down to around 8 while the max rises to 500.
#
# What are the possible actions that can be performed?
#     The possible actions that can be performed are move left (0) and move right(1).
#
# What reinforcement algorithm is used for this problem?
#     As stated in a cartpole article (Surma, G. (2019) Cartpole - introduction to reinforcement learning (DQN - deep Q-learning), Medium. Medium. Available at: https://gsurma.medium.com/cartpole-introduction-to-reinforcement-learning-ed0eb5b58288 (Accessed: March 31, 2023). This is a Deep Q Reinforced learning algorithm.
#
#
# How does experience replay work in this algorithm?
#     Experience is used in this alogorithm to learn from its last attempts. This allows the algortihm to remeber what didn't work and what got it closer to completeion. It then uses that experience to begin from a different point to streamline its learning.
#
# What is the effect of introducing a discount factor for calculating the future rewards?
#     (KarnivaurusKarnivaurus                    6 et al. (1963) Understanding the role of the discount factor in reinforcement learning, Cross Validated. Available at: https://stats.stackexchange.com/questions/221402/understanding-the-role-of-the-discount-factor-in-reinforcement-learning#:~:text=The%20discount%20factor%20essentially%20determines,that%20produce%20an%20immediate%20reward. (Accessed: March 31, 2023).) Explains that the discount factor is what drives the aglorithm to care about rewards in the future. If the discount factor is 0, the aglorithm will only care about instant rewards. However, if it's 1, it will take into considersation future rewards and use past experince.
#
#
# Explain the neural network architecture that is used in the cartpole problem.
#     The nerual network architecture we are using for the cartpole problem is a sequential nerual network. This means that the model has layers and the system is able to process only 1 layer at a time. Thus, 1 input is inputted and 1 output is recieved.
#
# How does the neural network make the Q-learning algorithm more efficient?
#     The neural network is able to process our input with pre-defined parameters using the past experience from failed attempts. Using a sequential neural network allows us to determine how the algorithm navigates the network.
#
# What difference do you see in the algorithm performance when you increase or decrease the learning rate?
#     When decreasing the size of the learning rate, it takes a lot less time for the solution to be reached. When I increased the learning rate, it took nearly 30,000 attempts for the algorithm to solve the problem.
